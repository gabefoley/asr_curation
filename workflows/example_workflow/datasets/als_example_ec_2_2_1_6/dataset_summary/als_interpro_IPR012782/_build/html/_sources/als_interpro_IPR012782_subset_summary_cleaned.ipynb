# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/Users/uqgfoley/opt/miniconda3/envs/asr_curation/lib/python3.9/site-packages', '/Users/uqgfoley/Dropbox/Code/Python_Workspace/asr_curation/asr_curation/notebooks']); import pickle; snakemake = pickle.loads(b"\x80\x04\x95u\x08\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c\x8bworkflows/example_workflow/datasets/als_example_ec_2_2_1_6/subsets/als_interpro_IPR012782/als_example_ec_2_2_1_6_als_interpro_IPR012782.aln\x94\x8c\x99workflows/example_workflow/datasets/als_example_ec_2_2_1_6/subsets/als_interpro_IPR012782/csv/als_example_ec_2_2_1_6_als_interpro_IPR012782_alignment.csv\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x03aln\x94K\x00N\x86\x94\x8c\x03csv\x94K\x01N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x15\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x1b)}\x94\x8c\x05_name\x94h\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bh\x0fh\nh\x11h\x0bub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c\xb1workflows/example_workflow/datasets/als_example_ec_2_2_1_6/dataset_summary/als_example_ec_2_2_1_6/subsets/als_interpro_IPR012782/temp/als_interpro_IPR012782_subset_summary.ipynb\x94a}\x94(h\r}\x94\x8c\x07summary\x94K\x00N\x86\x94sh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bh,h)ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94]\x94(\x8c\x16Cross_reference_SUPFAM\x94\x8c\x17Cross_reference_PANTHER\x94\x8c\x0bLoop_Length\x94\x8c\nKARI_Class\x94\x8c\tEC_number\x94ea}\x94(h\r}\x94\x8c\x0fannotation_cols\x94K\x00N\x86\x94sh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bhCh;ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x16als_example_ec_2_2_1_6\x94\x8c\x16als_interpro_IPR012782\x94e}\x94(h\r}\x94(\x8c\x07dataset\x94K\x00N\x86\x94\x8c\x06subset\x94K\x01N\x86\x94uh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94b\x8c\x07dataset\x94hR\x8c\x06subset\x94hSub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c0/var/folders/xs/24s9hwqd191f2x7rhdy6_ryc0000gr/T\x94e}\x94(h\r}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94uh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bhmK\x01hoK\x01hqhjub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8c\xb1workflows/example_workflow/datasets/als_example_ec_2_2_1_6/dataset_summary/als_example_ec_2_2_1_6/subsets/als_interpro_IPR012782/temp/als_interpro_IPR012782_subset_summary.ipynb\x94a}\x94(h\r}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x13]\x94(h\x15h\x16eh\x15h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x15sNt\x94bh\x16h\x19h\x1b\x85\x94R\x94(h\x1b)}\x94h\x1fh\x16sNt\x94bh\x83h\x80ub\x8c\x06config\x94}\x94(\x8c\x07workdir\x94\x8c\x1aworkflows/example_workflow\x94\x8c\x08fastadir\x94\x8c workflows/example_workflow/fasta\x94\x8c\x06subdir\x94\x8c'workflows/example_workflow/subset_rules\x94\x8c\x0fannotation_cols\x94]\x94(h<h=h>h?h@e\x8c\x10blocked_datasets\x94]\x94u\x8c\x04rule\x94\x8c\x15create_subset_summary\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cQ/Users/uqgfoley/Dropbox/Code/Python_Workspace/asr_curation/asr_curation/notebooks\x94ub."); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/Users/uqgfoley/Dropbox/Code/Python_Workspace/asr_curation/asr_curation');
######## snakemake preamble end #########

# %%
import matplotlib.pyplot as plt
from collections import defaultdict
import py3Dmol
import pandas as pd
import re
import requests
from IPython.display import display, Markdown

# %%
base_url = "https://www.ebi.ac.uk/pdbe/"

api_base = base_url + "api/"

summary_url = api_base + 'pdb/entry/summary/'
secondary_structure_url = api_base + 'pdb/entry/secondary_structure/'
ligand_url = api_base + '/pdb/entry/ligand_monomers/'


def make_summary(data):
    """
    This function creates a summary for a PDB entry
    by getting data for an entry, and extracting
    pieces of information
    
    :param data: Dict
    :return: String
    """
    
    pdb_id = ""
    # Certain calls could return multiple PDB entries,
    # but the GET summary call we use in this exercise
    # will always return only one PDB entry
    for key in data.keys():
        pdb_id = key

    # The data is a list of dictionaries, and for the summary information,
    # it is always the first element of the list
    entry = data[pdb_id][0]
    
    # Getting the title of the entry
    title = entry['title']
    
    # Getting the release date of the entry
    release_date = entry['release_date']
    # Formatting the entry to make it more user-friendly
    formatted_release_date = "%s/%s/%s" % (
        release_date[:4], 
        release_date[4:6], 
        release_date[6:])
    
    # Getting the experimental methods
    # Note that there can be multiple methods, so this is a list that
    # needs to be iterated
    experimental_methods = ""
    for experimental_method in entry["experimental_method"]:
        if experimental_methods:
            experimental_methods += " and "
        experimental_methods += experimental_method
        
        
        
    # Getting the assemblies
    assemblies = ''
    for assembly in entry['assemblies']:
        if assembly:
            # Blank out the form if it is a monomer (because it must be homo form)
            if assembly['name'] == 'monomer':
                form = ""
            else:
                form = assembly['form']
                
            if assembly['preferred']:
                
                assemblies += f"Preferred form with assembly ID {assembly['assembly_id']} is a {form}{assembly['name']}\n"
            else:
                assemblies += f"Non-preferred form with assembly ID {assembly['assembly_id']} is a {assembly['form']}{assembly['name']}\n"

    # Getting the author list
    authors = "".join(entry['entry_authors'])
    
#         'assemblies': [{'assembly_id': '1', 'form': 'homo', 'preferred': True, 'name': 'monomer'}, {'assembly_id': '2', 'form': 'homo', 'preferred': False, 'name': 'dimer'}]}]}
    
    
        
     
    # Creating the summary text using all the extracted 
    # information
    summary = f'Entry is titled "{title}" and was released on {formatted_release_date} \n\nThis entry was determined using {experimental_methods} \nThe authors are {authors} \n\nAssembly information -\n{assemblies}'

    return summary

def make_request(url, mode, pdb_id):
    """
    This function can make GET and POST requests to
    the PDBe API
    
    :param url: String,
    :param mode: String,
    :param pdb_id: String
    :return: JSON or None
    """
    if mode == "get":
        response = requests.get(url=url+pdb_id)
    elif mode == "post":
        response = requests.post(url, data=pdb_id)

    if response.status_code == 200:
        return response.json()
    else:
        print("[No data retrieved - %s] %s" % (response.status_code, response.text))
    
    return None

def get_secondary_structure_ranges(pdb_id=None, pdb_list=None):
    """
    This function calls the PDBe API and retrieves the residue
    ranges of secondary structural elements in a single PDB entry
    or in a list of PDB entries
    
    :param pdb_id: String,
    :param pdb_list: String
    :return: None
    """
    # If neither a single PDB id, nor a list was provided,
    # exit the function
    if not pdb_id and not pdb_list:
        print("Either provide one PDB id, or a list of ids")
        return None
    
    if pdb_id:
        # If a single PDB id was provided, call the API with GET
        data = make_request(secondary_structure_url, "get", pdb_id)
    else:
        # If multiple PDB ids were provided, call the API with POST
        # The POST API call expects PDB ids as a comma-separated lise
        pdb_list_string = ", ".join(pdb_list)
        data = make_request(secondary_structure_url, "post", pdb_list_string)
        
    # When no data is returned by the API, exit the function
    if not data:
        print("No data available")
        return None
    
    # Loop through all the PDB entries in the retrieved data
    for entry_id in data.keys():
        entry = data[entry_id]
        molecules = entry["molecules"]
        
        # Loop through all the molecules of a given PDB entry
        for i in range(len(molecules)):
            chains = molecules[i]["chains"]
            
            # Loop through all the chains of a given molecules
            for j in range(len(chains)):
                secondary_structure = chains[j]["secondary_structure"]
                helices = secondary_structure["helices"]
                strands = secondary_structure["strands"]
                helix_list = []
                strand_list = []
                
                # Loop through all the helices of a given chain
                for k in range(len(helices)):
                    start = helices[k]["start"]["residue_number"]
                    end = helices[k]["end"]["residue_number"]
                    helix_list.append("%s-%s" % (start, end))
                
                # Loop through all the strands of a given chain
                for l in range(len(strands)):
                    start = strands[l]["start"]["residue_number"]
                    end = strands[l]["end"]["residue_number"]
                    strand_list.append("%s-%s" % (start, end))
                    
                report = "%s chain %s has " % (entry_id, chains[j]["chain_id"])
                if len(helix_list) > 0:
                    report += "helices at residue ranges %s " % str(helix_list)
                else:
                    report += "no helices "
                report += "and "
                if len(strand_list) > 0:
                    report += "strands at %s" % str(strand_list)
                else:
                    "no strands"
                print(report)
                
    return None

def get_ligand_information(data):
    pdb_id = ""
    
    summary = ""

    for key in data.keys():
        pdb_id = key
        
    for ligand in data[pdb_id]:
        summary += f"Ligand : {ligand['chem_comp_name']} at position {ligand['author_residue_number']}\n"
        
    return summary
    

def get_entry_from_api(pdb_id, api_url):
    """
    This function will make a call to the PDBe API using
    the PDB id and API url provided as arguments
    
    :param pdb_id: String,
    :param api_url: String
    :return: Dict or None
    """
    if not re.match("[0-9][A-Za-z][A-Za-z0-9]{2}", pdb_id):
        print("Invalid PDB id")
        return None
    
    # Make a GET call to the API URL
    get_request = requests.get(url=api_url+pdb_id)
    
    if get_request.status_code == 200:
        # If there is data returned (with HTML status code 200)
        # then return the data in JSON format
        return get_request.json()
    else:
        # If there is no data, print status code and response
        print(get_request.status_code, get_request.text)
        return None


# As you can hopefully see, the data displayed is very similar to
# what we had in the mock data in previous sections - however,
# this is actual data coming from the PDBe API

# %%
print(display(Markdown(f'# Subset - {snakemake.wildcards.subset}')))
# Out:
# # Subset - als_interpro_IPR012782
# None

# %%
print (f'Subset sheet - {snakemake.wildcards.subset}')
# Out:
# Subset sheet - als_interpro_IPR012782

# %%
df = pd.read_csv(snakemake.input.csv)
non_fragment_df = df[df['fragment'] == False]
entry_df = df.dropna(axis=1, how='all')

# %% [markdown]
# # EC numbers

# %%
ec_nums = list(pd.unique(df['ec']))

ec_set = set()

for num in ec_nums:
    for split in str(num).split(";"):
        ec_set.add(split.strip())
    
print (f'The EC numbers found in the current data set are {ec_set}')
# Out:
# The EC numbers found in the current data set are {'2.2.1.6'}

# %% [markdown]
# # Taxonomic distribution

# %%
taxonomy_cols = ['lineage_superkingdom', 'lineage_phylum']

for col in taxonomy_cols:
    fig, ax = plt.subplots(figsize=(len(col) / 4 ,10))
    chart = df[col].value_counts().plot.barh(title=col, ax=ax)
    plt.show()

# %% [markdown]
# # Annotation distributions

# %%
key_annotation_cols = snakemake.params.annotation_cols

for col in key_annotation_cols:
    if col in entry_df:
        fig, ax = plt.subplots(figsize=(len(col) / 3 ,10))
        chart = entry_df[col].value_counts().plot.barh(title=col, ax=ax)
        plt.show()

# %%
seq_len = df['length'].describe()
non_fragment_seq_len = non_fragment_df['length'].describe()



def print_sequence_summarys(seq_summary):
    print (f"Number of sequences : {seq_summary['count']}")
    print (f"Smallest sequnce length : {seq_summary['min']}")
    print (f"Longest sequnce length : {seq_summary['max']}")
    print (f"Average sequnce length : {seq_summary['mean']}")

print ("Sequence statistics for all sequences")
print_sequence_summarys(seq_len)

print ()

if non_fragment_seq_len.all():

    print ("Sequence statistics for sequences (non-fragments)")
    print_sequence_summarys(non_fragment_seq_len)
# Out:
# Sequence statistics for all sequences
# Number of sequences : 3.0
# Smallest sequnce length : 559.0
# Longest sequnce length : 570.0
# Average sequnce length : 562.6666666666666

# %% [markdown]
# # Experimental data (BRENDA)

# %%
skip_brenda_cols = [
'BRENDA_CL', 'BRENDA_GI', 
'BRENDA_SN', 'BRENDA_SY', 
'BRENDA_MW', 'BRENDA_SP',
'BRENDA_NSP', 'BRENDA_PM',
'BRENDA_LO', 'BRENDA_SU', 
'BRENDA_PU', 'BRENDA_ST',
'BRENDA_CR', 'BRENDA_CF',
'BRENDA_RN', 'BRENDA_RT',
'BRENDA_ME', 'BRENDA_REFERENCES']


# Only get the columns that start with BRENDA and that we don't want to skip
brenda_cols =[x for x in df if x.startswith("BRENDA") and 'COMMENT' not in x and 'REFS' not in x and 'UNITS' not in x and not any(skip in x for skip in skip_brenda_cols)]

# Drop rows if they don't have at least one entry in one of the BRENDA columns
b_df = df[brenda_cols].dropna(thresh=1)
print (len(brenda_cols))
fig, ax = plt.subplots(figsize=(len(brenda_cols) / 4 ,10))


# Create and save a plot of the BRENDA column counts
if not b_df.empty:
    b_df.count().plot.barh(ax=ax)
    display()
# Out:
# 166

# %% [markdown]
# # Structural information

# %%
pdb_df = df[['accession', 'xref_pdb']].dropna()
pdb_dict = defaultdict(list)
for pdb_entries in pdb_df.itertuples():
    pdb_dict[pdb_entries.accession] = [x for x in pdb_entries.xref_pdb.strip().split(";") if len(x) > 0]

total_structures = sum([len(x) for x in pdb_dict.values()])

print (f"There are {total_structures} total structures across {len(pdb_dict.keys())} unique sequences")

print ("Looking at the first few...")

sample_pdb_dict = {k: pdb_dict[k] for k in list(pdb_dict)[:3]}

for prot_id, pdb_ids in sample_pdb_dict.items():
    for pdb_id in pdb_ids:
        
        print(display(Markdown(f'# {pdb_id} PDB entry information')))

        print(make_summary(get_entry_from_api(pdb_id, summary_url)))
        
        display(Markdown(f'# {pdb_id} Ligand informtion'))    
        print(get_ligand_information(get_entry_from_api(pdb_id, ligand_url)))
        
    
        display(Markdown(f'# {pdb_id} Secondary structure ranges'))
        get_secondary_structure_ranges(pdb_id)
        
        display(Markdown(f'# {pdb_id}'))
        
        view = py3Dmol.view(query=f'pdb:{pdb_id}')
        view.setStyle({'cartoon':{'color':'spectrum'}})
        display(view)
# Out:
# There are 6 total structures across 1 unique sequences
# Looking at the first few...
# # 1OZF PDB entry information
# None
# Entry is titled "The crystal structure of Klebsiella pneumoniae acetolactate synthase with enzyme-bound cofactors" and was released on 2003/11/11
#
# This entry was determined using X-ray diffraction
# The authors are Pang, S.S.Duggleby, R.G.Schowen, R.L.Guddat, L.W.
#
# Assembly information -
# Preferred form with assembly ID 1 is a homotetramer
# # 1OZF Ligand informtion
# Ligand : PHOSPHATE ION at position 697
# Ligand : PHOSPHATE ION at position 703
# Ligand : MAGNESIUM ION at position 699
# Ligand : MAGNESIUM ION at position 704
# Ligand : THIAMINE DIPHOSPHATE at position 700
# Ligand : THIAMINE DIPHOSPHATE at position 705
# Ligand : DI(HYDROXYETHYL)ETHER at position 690
# Ligand : DI(HYDROXYETHYL)ETHER at position 691
# Ligand : DI(HYDROXYETHYL)ETHER at position 692
# Ligand : DI(HYDROXYETHYL)ETHER at position 693
# Ligand : DI(HYDROXYETHYL)ETHER at position 694
# Ligand : DI(HYDROXYETHYL)ETHER at position 695
# Ligand : DI(HYDROXYETHYL)ETHER at position 696
# Ligand : DI(HYDROXYETHYL)ETHER at position 701
# Ligand : DI(HYDROXYETHYL)ETHER at position 702
# # 1OZF Secondary structure ranges
# 1ozf chain A has helices at residue ranges ['12-24', '34-36', '37-45', '56-72', '82-87', '88-99', '123-129', '130-132', '140-142', '143-157', '169-174', '193-207', '216-220', '220-222', '223-235', '242-245', '249-253', '266-275', '284-288', '289-293', '323-333', '342-360', '372-384', '395-404', '405-408', '424-436', '447-454', '455-464', '477-489', '500-507', '517-519', '520-531', '545-551'] and strands at ['176-178', '50-53', '75-79', '28-32', '102-108', '162-168', '134-137', '8-10', '238-240', '277-281', '256-259', '210-214', '299-304', '318-321', '412-414', '440-446', '388-392', '467-473', '535-540', '511-514']
# 1ozf chain B has helices at residue ranges ['12-24', '37-45', '56-72', '82-87', '88-99', '110-114', '123-129', '130-132', '140-142', '143-157', '169-174', '193-207', '216-220', '220-222', '223-235', '242-245', '266-275', '284-288', '289-293', '323-333', '342-361', '372-384', '395-404', '405-408', '424-436', '447-454', '455-464', '477-489', '500-508', '517-519', '520-530', '542-544', '545-551'] and strands at ['176-178', '50-53', '75-79', '28-32', '102-108', '162-168', '134-137', '8-10', '238-240', '277-281', '256-259', '210-214', '299-304', '318-321', '412-414', '441-446', '389-392', '467-473', '535-540', '511-514']
# # 1OZF
# <div id="3dmolviewer_1663142408601832"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1663142408601832" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_1663142408601832 = null;
# var warn = document.getElementById("3dmolwarning_1663142408601832");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1663142408601832 = $3Dmol.createViewer($("#3dmolviewer_1663142408601832"),{backgroundColor:"white"});
# $3Dmol.download("pdb:1OZF", viewer_1663142408601832, {}, function() {
# viewer_1663142408601832.zoomTo();
# 	viewer_1663142408601832.setStyle({"cartoon": {"color": "spectrum"}});
# viewer_1663142408601832.render();
# })
# });
# </script>
# # 1OZG PDB entry information
# None
# Entry is titled "The crystal structure of Klebsiella pneumoniae acetolactate synthase with enzyme-bound cofactor and with an unusual intermediate" and was released on 2003/11/04
#
# This entry was determined using X-ray diffraction
# The authors are Pang, S.S.Duggleby, R.G.Schowen, R.L.Guddat, L.W.
#
# Assembly information -
# Preferred form with assembly ID 1 is a homotetramer
# # 1OZG Ligand informtion
# Ligand : PHOSPHATE ION at position 697
# Ligand : PHOSPHATE ION at position 703
# Ligand : MAGNESIUM ION at position 699
# Ligand : MAGNESIUM ION at position 704
# Ligand : 2-HYDROXYETHYL DIHYDROTHIACHROME DIPHOSPHATE at position 700
# Ligand : 2-HYDROXYETHYL DIHYDROTHIACHROME DIPHOSPHATE at position 705
# Ligand : DI(HYDROXYETHYL)ETHER at position 691
# Ligand : DI(HYDROXYETHYL)ETHER at position 692
# Ligand : DI(HYDROXYETHYL)ETHER at position 693
# Ligand : DI(HYDROXYETHYL)ETHER at position 694
# Ligand : DI(HYDROXYETHYL)ETHER at position 695
# Ligand : DI(HYDROXYETHYL)ETHER at position 696
# Ligand : DI(HYDROXYETHYL)ETHER at position 701
# Ligand : DI(HYDROXYETHYL)ETHER at position 702
# # 1OZG Secondary structure ranges
# 1ozg chain A has helices at residue ranges ['12-25', '37-46', '56-72', '82-87', '88-99', '113-118', '123-129', '130-132', '140-142', '143-157', '169-174', '193-207', '216-220', '220-222', '223-235', '242-245', '266-275', '284-288', '289-293', '323-333', '342-360', '372-384', '395-404', '405-408', '424-436', '447-454', '456-464', '477-489', '500-507', '517-519', '520-530', '542-544', '545-551'] and strands at ['176-178', '50-53', '75-79', '28-32', '102-108', '162-168', '134-137', '8-10', '238-240', '277-281', '256-259', '210-214', '299-304', '318-321', '412-414', '440-446', '388-392', '467-473', '535-540', '511-514']
# 1ozg chain B has helices at residue ranges ['12-24', '37-45', '56-72', '82-87', '88-99', '110-114', '123-129', '130-132', '140-142', '143-157', '169-174', '193-207', '216-220', '223-235', '242-245', '266-275', '284-288', '289-294', '323-333', '342-362', '372-384', '395-404', '405-408', '424-436', '447-454', '456-464', '477-489', '500-508', '517-519', '520-530', '542-544', '545-551'] and strands at ['176-178', '50-53', '75-79', '28-32', '102-108', '162-168', '134-137', '8-10', '238-240', '277-281', '256-259', '210-214', '299-304', '318-321', '412-414', '441-446', '389-392', '467-473', '535-540', '511-514']
# # 1OZG
# <div id="3dmolviewer_1663142413443661"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1663142413443661" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_1663142413443661 = null;
# var warn = document.getElementById("3dmolwarning_1663142413443661");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1663142413443661 = $3Dmol.createViewer($("#3dmolviewer_1663142413443661"),{backgroundColor:"white"});
# $3Dmol.download("pdb:1OZG", viewer_1663142413443661, {}, function() {
# viewer_1663142413443661.zoomTo();
# 	viewer_1663142413443661.setStyle({"cartoon": {"color": "spectrum"}});
# viewer_1663142413443661.render();
# })
# });
# </script>
# # 1OZH PDB entry information
# None
# Entry is titled "The crystal structure of Klebsiella pneumoniae acetolactate synthase with enzyme-bound cofactor and with an unusual intermediate." and was released on 2003/11/04
#
# This entry was determined using X-ray diffraction
# The authors are Pang, S.S.Duggleby, R.G.Schowen, R.L.Guddat, L.W.
#
# Assembly information -
# Preferred form with assembly ID 1 is a homotetramer
# # 1OZH Ligand informtion
# Ligand : PHOSPHATE ION at position 1404
# Ligand : PHOSPHATE ION at position 1411
# Ligand : PHOSPHATE ION at position 1421
# Ligand : PHOSPHATE ION at position 1431
# Ligand : MAGNESIUM ION at position 1405
# Ligand : MAGNESIUM ION at position 1412
# Ligand : MAGNESIUM ION at position 1422
# Ligand : MAGNESIUM ION at position 1432
# Ligand : TRIETHYLENE GLYCOL at position 1402
# Ligand : TRIETHYLENE GLYCOL at position 1403
# Ligand : 2-HYDROXYETHYL DIHYDROTHIACHROME DIPHOSPHATE at position 1406
# Ligand : 2-HYDROXYETHYL DIHYDROTHIACHROME DIPHOSPHATE at position 1413
# Ligand : 2-HYDROXYETHYL DIHYDROTHIACHROME DIPHOSPHATE at position 1423
# Ligand : 2-HYDROXYETHYL DIHYDROTHIACHROME DIPHOSPHATE at position 1433
# Ligand : DI(HYDROXYETHYL)ETHER at position 1401
# Ligand : DI(HYDROXYETHYL)ETHER at position 1400
# Ligand : DI(HYDROXYETHYL)ETHER at position 1410
# Ligand : DI(HYDROXYETHYL)ETHER at position 1420
# Ligand : DI(HYDROXYETHYL)ETHER at position 1430
# # 1OZH Secondary structure ranges
# 1ozh chain A has helices at residue ranges ['12-24', '37-44', '45-47', '56-72', '82-87', '88-99', '123-129', '130-132', '140-142', '143-157', '169-174', '193-207', '216-220', '220-222', '223-235', '242-245', '266-275', '284-288', '289-293', '323-334', '342-361', '372-384', '395-404', '405-408', '424-436', '447-454', '455-464', '477-489', '500-507', '517-519', '520-531', '545-551', '554-557'] and strands at ['176-178', '50-53', '75-79', '28-32', '102-108', '162-168', '134-137', '8-10', '238-240', '277-281', '256-259', '210-214', '299-304', '318-321', '412-414', '440-446', '388-392', '467-473', '535-540', '511-514', '188-189']
# 1ozh chain B has helices at residue ranges ['12-24', '37-44', '45-47', '56-72', '82-87', '88-99', '123-129', '130-132', '140-142', '143-157', '169-174', '193-207', '216-220', '223-235', '242-245', '266-275', '284-288', '289-293', '323-334', '342-361', '372-384', '395-404', '405-408', '424-436', '447-454', '455-464', '477-489', '500-507', '517-519', '520-530', '545-551', '554-558'] and strands at ['176-177', '50-53', '75-79', '28-32', '102-108', '162-168', '134-137', '9-10', '238-240', '277-281', '256-259', '210-214', '299-304', '318-321', '412-414', '441-446', '389-392', '467-473', '535-540', '511-514']
# 1ozh chain C has helices at residue ranges ['12-25', '37-45', '56-72', '82-87', '88-99', '110-114', '123-129', '130-132', '140-142', '143-157', '169-174', '193-207', '216-220', '220-222', '223-235', '242-245', '266-275', '284-288', '289-293', '323-334', '342-360', '372-384', '395-404', '405-408', '424-436', '447-454', '455-464', '477-489', '500-507', '520-531', '545-551', '553-558'] and strands at ['176-177', '50-53', '75-79', '28-32', '102-108', '162-168', '134-137', '9-10', '238-240', '277-281', '256-259', '210-214', '299-304', '318-321', '412-414', '441-446', '389-392', '467-473', '535-540', '511-514']
# 1ozh chain D has helices at residue ranges ['12-24', '34-36', '37-46', '56-72', '82-87', '88-99', '110-114', '123-129', '130-132', '140-142', '143-157', '169-174', '193-206', '216-220', '220-222', '223-235', '242-245', '249-253', '266-275', '284-288', '289-293', '323-334', '342-360', '372-384', '395-404', '405-408', '424-436', '447-454', '455-464', '477-489', '500-507', '520-531', '545-551'] and strands at ['318-321', '176-178', '50-53', '75-79', '28-31', '102-108', '162-168', '134-137', '8-10', '238-240', '277-281', '256-259', '210-214', '299-304', '412-414', '441-446', '389-392', '467-473', '535-540', '511-514']
# # 1OZH
# <div id="3dmolviewer_1663142418582117"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1663142418582117" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_1663142418582117 = null;
# var warn = document.getElementById("3dmolwarning_1663142418582117");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1663142418582117 = $3Dmol.createViewer($("#3dmolviewer_1663142418582117"),{backgroundColor:"white"});
# $3Dmol.download("pdb:1OZH", viewer_1663142418582117, {}, function() {
# viewer_1663142418582117.zoomTo();
# 	viewer_1663142418582117.setStyle({"cartoon": {"color": "spectrum"}});
# viewer_1663142418582117.render();
# })
# });
# </script>
# # 5D6R PDB entry information
# None
# Entry is titled "Acetolactate Synthase from Klebsiella pneumoniae in Complex with Mechanism-Based Inhibitor" and was released on 2016/07/20
#
# This entry was determined using X-ray diffraction
# The authors are Latta, A.J.Andrews, F.H.McLeish, M.J.
#
# Assembly information -
# Preferred form with assembly ID 1 is a homotetramer
# # 5D6R Ligand informtion
# Ligand : MAGNESIUM ION at position 601
# Ligand : MAGNESIUM ION at position 602
# Ligand : MAGNESIUM ION at position 603
# Ligand : MAGNESIUM ION at position 601
# Ligand : MAGNESIUM ION at position 602
# Ligand : PHOSPHATE ION at position 604
# Ligand : PHOSPHATE ION at position 603
# Ligand : 3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-2-[(Z)-2-fluoro-1-hydroxy-2-phosphonoethenyl]-5-(2-{[(S)-hydroxy(phosphonooxy)phosphoryl]oxy}ethyl)-4-methyl-1,3-thiazol-3-ium at position 605
# Ligand : 3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-2-[(Z)-2-fluoro-1-hydroxy-2-phosphonoethenyl]-5-(2-{[(S)-hydroxy(phosphonooxy)phosphoryl]oxy}ethyl)-4-methyl-1,3-thiazol-3-ium at position 604
# # 5D6R Secondary structure ranges
# 5d6r chain B has helices at residue ranges ['32-44', '57-64', '65-67', '76-92', '102-107', '108-119', '130-134', '143-149', '150-152', '160-162', '163-177', '189-194', '213-227', '236-240', '240-242', '243-255', '262-265', '286-295', '304-308', '309-313', '343-353', '362-381', '392-404', '415-424', '425-428', '444-456', '467-474', '476-484', '497-509', '520-527', '537-539', '540-550', '562-564', '565-571'] and strands at ['196-198', '70-73', '95-99', '48-52', '122-128', '182-188', '154-157', '28-30', '258-260', '297-301', '276-279', '230-234', '319-324', '338-341', '432-434', '460-466', '408-412', '487-493', '555-560', '531-534']
# 5d6r chain M has helices at residue ranges ['32-44', '57-64', '65-67', '76-92', '102-107', '108-119', '130-134', '143-149', '150-152', '160-162', '163-177', '189-194', '213-227', '236-240', '240-242', '243-255', '262-265', '286-295', '304-308', '309-313', '343-353', '362-377', '392-404', '415-424', '425-428', '444-456', '467-474', '476-484', '497-509', '520-527', '537-539', '540-550', '562-564', '565-571'] and strands at ['196-198', '70-73', '95-99', '48-51', '122-128', '182-188', '154-157', '28-30', '258-260', '297-301', '276-279', '230-234', '319-324', '338-341', '432-434', '460-466', '408-412', '487-493', '555-560', '531-534']
# # 5D6R
# <div id="3dmolviewer_16631424226022022"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_16631424226022022" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_16631424226022022 = null;
# var warn = document.getElementById("3dmolwarning_16631424226022022");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16631424226022022 = $3Dmol.createViewer($("#3dmolviewer_16631424226022022"),{backgroundColor:"white"});
# $3Dmol.download("pdb:5D6R", viewer_16631424226022022, {}, function() {
# viewer_16631424226022022.zoomTo();
# 	viewer_16631424226022022.setStyle({"cartoon": {"color": "spectrum"}});
# viewer_16631424226022022.render();
# })
# });
# </script>
# # 5DX6 PDB entry information
# None
# Entry is titled "Acetolactate Synthase from Klebsiella pneumoniae soaked with beta-fluoropyruvate" and was released on 2016/09/28
#
# This entry was determined using X-ray diffraction
# The authors are Latta, A.J.McLeish, M.J.Andrews, F.H.
#
# Assembly information -
# Preferred form with assembly ID 1 is a homotetramer
# # 5DX6 Ligand informtion
# Ligand : PHOSPHATE ION at position 601
# Ligand : MAGNESIUM ION at position 602
# Ligand : MAGNESIUM ION at position 603
# Ligand : MAGNESIUM ION at position 601
# Ligand : MAGNESIUM ION at position 602
# Ligand : 3-[(4-amino-2-methylpyrimidin-5-yl)methyl]-2-[(1R)-2-fluoro-1-hydroxyethyl]-5-(2-{[(S)-hydroxy(phosphonooxy)phosphoryl]oxy}ethyl)-4-methyl-1,3-thiazol-3-ium at position 604
# Ligand : THIAMINE DIPHOSPHATE at position 603
# Ligand : 3-fluoro-2-oxopropanoic acid at position 604
# # 5DX6 Secondary structure ranges
# 5dx6 chain A has helices at residue ranges ['32-44', '54-56', '57-65', '76-92', '102-107', '108-119', '130-136', '143-149', '150-152', '160-162', '163-177', '189-194', '213-227', '236-240', '240-242', '243-255', '286-295', '304-308', '309-313', '343-354', '362-381', '392-404', '415-424', '425-428', '444-456', '467-474', '475-484', '497-509', '520-527', '540-551', '562-564', '565-571'] and strands at ['196-198', '70-73', '95-99', '48-52', '122-128', '182-188', '154-157', '28-30', '258-260', '297-301', '276-279', '230-234', '319-324', '338-341', '432-434', '461-466', '409-412', '487-493', '555-560', '531-534']
# 5dx6 chain B has helices at residue ranges ['32-44', '54-56', '57-65', '76-92', '102-107', '108-119', '130-134', '136-140', '143-149', '150-152', '160-162', '163-177', '189-194', '213-227', '236-240', '240-242', '243-255', '263-265', '286-295', '304-308', '309-314', '343-354', '362-374', '392-404', '415-424', '425-428', '444-456', '467-474', '475-484', '497-509', '520-527', '537-539', '540-551', '565-571', '574-578'] and strands at ['196-198', '70-73', '95-99', '48-52', '122-128', '182-188', '154-157', '28-30', '258-261', '297-301', '276-280', '230-234', '319-324', '338-341', '432-434', '461-466', '409-412', '487-493', '555-560', '531-534']
# # 5DX6
# <div id="3dmolviewer_1663142426631992"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1663142426631992" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_1663142426631992 = null;
# var warn = document.getElementById("3dmolwarning_1663142426631992");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1663142426631992 = $3Dmol.createViewer($("#3dmolviewer_1663142426631992"),{backgroundColor:"white"});
# $3Dmol.download("pdb:5DX6", viewer_1663142426631992, {}, function() {
# viewer_1663142426631992.zoomTo();
# 	viewer_1663142426631992.setStyle({"cartoon": {"color": "spectrum"}});
# viewer_1663142426631992.render();
# })
# });
# </script>
# # 5WDG PDB entry information
# None
# Entry is titled "Acetolactate Synthase from Klebsiella pneumoniae in Complex with a Reaction Intermediate" and was released on 2018/07/11
#
# This entry was determined using X-ray diffraction
# The authors are Latta, A.J.Andrews, F.H.McLeish, M.J.
#
# Assembly information -
# Preferred form with assembly ID 1 is a homotetramer
# # 5WDG Ligand informtion
# Ligand : MAGNESIUM ION at position 601
# Ligand : MAGNESIUM ION at position 602
# Ligand : MAGNESIUM ION at position 603
# Ligand : MAGNESIUM ION at position 601
# Ligand : MAGNESIUM ION at position 602
# Ligand : MAGNESIUM ION at position 603
# Ligand : PHOSPHATE ION at position 604
# Ligand : PHOSPHATE ION at position 604
# Ligand : (2S,3S)-2,3-dihydroxy-3-[(7S,8R,9aS)-8-(2-{[(R)-hydroxy(phosphonooxy)phosphoryl]oxy}ethyl)-2,7-dimethyl-5,7,8,10-tetrahydro-9aH-pyrimido[4,5-d][1,3]thiazolo[3,2-a]pyrimidin-9a-yl]-2-methylbutanoic acid at position 605
# Ligand : (2S,3S)-2,3-dihydroxy-3-[(7S,8R,9aS)-8-(2-{[(R)-hydroxy(phosphonooxy)phosphoryl]oxy}ethyl)-2,7-dimethyl-5,7,8,10-tetrahydro-9aH-pyrimido[4,5-d][1,3]thiazolo[3,2-a]pyrimidin-9a-yl]-2-methylbutanoic acid at position 605
# Ligand : PYRUVIC ACID at position 606
# Ligand : PYRUVIC ACID at position 606
# # 5WDG Secondary structure ranges
# 5wdg chain A has helices at residue ranges ['32-44', '57-66', '76-92', '102-107', '108-119', '130-134', '143-149', '150-152', '160-162', '163-177', '189-194', '213-227', '236-240', '240-242', '243-255', '262-265', '286-295', '304-308', '309-313', '343-354', '362-380', '392-404', '415-424', '425-428', '444-456', '467-474', '476-484', '497-509', '520-528', '540-550', '562-564', '565-571'] and strands at ['196-199', '70-73', '95-99', '48-51', '122-128', '182-188', '154-157', '27-30', '258-260', '297-301', '276-279', '230-234', '319-324', '338-341', '432-434', '461-466', '409-412', '487-493', '555-560', '531-534']
# 5wdg chain B has helices at residue ranges ['32-44', '57-64', '65-67', '76-92', '102-107', '108-119', '130-135', '143-149', '150-152', '160-162', '163-177', '189-194', '213-227', '236-240', '240-242', '243-255', '262-265', '286-295', '304-308', '309-313', '343-354', '362-376', '392-404', '415-424', '425-428', '444-456', '467-474', '476-484', '497-509', '520-528', '537-539', '540-550', '562-564', '565-571'] and strands at ['196-198', '70-73', '95-99', '48-51', '122-128', '182-188', '154-157', '28-30', '258-260', '297-301', '276-279', '230-234', '319-324', '338-341', '432-434', '460-466', '408-412', '487-493', '555-560', '531-534']
# # 5WDG
# <div id="3dmolviewer_1663142431307591"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1663142431307591" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@latest/build/3Dmol-min.min.js');
# }
#
# var viewer_1663142431307591 = null;
# var warn = document.getElementById("3dmolwarning_1663142431307591");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1663142431307591 = $3Dmol.createViewer($("#3dmolviewer_1663142431307591"),{backgroundColor:"white"});
# $3Dmol.download("pdb:5WDG", viewer_1663142431307591, {}, function() {
# viewer_1663142431307591.zoomTo();
# 	viewer_1663142431307591.setStyle({"cartoon": {"color": "spectrum"}});
# viewer_1663142431307591.render();
# })
# });
# </script>

# %% [markdown]
# <!-- # Alignment information -->

# %%
# Alignment information (not working at the moment)
# print ('Make this work on server')
# import sequence
# subset_aln = sequence.readFastaFile(f"{snakemake.input.aln}")
# display(Markdown(f'Alignment has a length of {len(subset_aln[0].sequence)} positions'))
